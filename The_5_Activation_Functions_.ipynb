# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-5, 5, 100)
plt.plot(x, 1 / (1 + np.exp(-x)), label='Sigmoid')
plt.plot(x, np.tanh(x), label='tanh')
plt.plot(x, np.maximum(0, x), label='ReLU')
plt.plot(x, x, label='Identity')
plt.plot(x, np.exp(x) / np.sum(np.exp(x)), label='Softmax')

plt.xlabel('Input')
plt.ylabel('Activation')
plt.title('Activation Functions')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# The 5 Activation Functions — Detailed Explanation
# 1. Sigmoid — 1 / (1 + e^(-x))
#
# Output range: (0, 1)
# Shape: S-curve
# Use case: Binary classification (output layer), older hidden layers
# Problem: Vanishing gradient — for large/small inputs, gradient ≈ 0, so learning stops
# Key property: Outputs can be interpreted as probabilities
#
# 2. Tanh — tanh(x)
#
# Output range: (-1, 1)
# Shape: S-curve, centered at 0
# Use case: Hidden layers in RNNs
# Advantage over Sigmoid: Zero-centered, so gradients don't all push in one direction
# Still has: Vanishing gradient problem at extremes
#
# 3. ReLU — max(0, x)
#
# Output range: [0, ∞)
# Shape: Flat for x<0, linear for x>0
# Use case: Hidden layers in most modern CNNs, deep networks
# Advantage: No vanishing gradient for positive inputs, computationally cheap
# Problem: "Dying ReLU" — neurons stuck at 0 if they receive only negative inputs
#
# 4. Identity (Linear) — f(x) = x
#
# Output range: (-∞, ∞)
# Use case: Output layer for regression tasks
# Key point: No non-linearity — if all layers used this, the whole network collapses to one linear transformation
#
# 5. Softmax — e^x / Σe^x
#
# Output range: (0, 1), sums to 1 across all classes
# Use case: Output layer for multi-class classification
# Key property: Converts a vector of scores into a probability distribution
# Note: In your code it's applied to a 1D array (not a vector of class scores), which is why the plot looks small — in practice it takes a vector input
